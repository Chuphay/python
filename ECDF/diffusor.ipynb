# %%
import torch
from torch import autocast
from diffusers import StableDiffusionPipeline

pipe = StableDiffusionPipeline.from_pretrained(
    'hakurei/waifu-diffusion',
    torch_dtype=torch.float16,
    num_inference_steps=16,
    revision="fp16"
)

# prompt = "1girl, aqua eyes, baseball cap, blonde hair, closed mouth, earrings, green background, hat, hoop earrings, jewelry, looking at viewer, shirt, short hair, simple background, solo, upper body, yellow shirt"
# with autocast("cuda"):
# Out:
# Fetching 15 files:   0%|          | 0/15 [00:00<?, ?it/s]
# Keyword arguments {'num_inference_steps': 16} are not expected by StableDiffusionPipeline and will be ignored.
# ftfy or spacy is not installed using BERT BasicTokenizer instead of ftfy.

# %%
prompt = "girl"
image = pipe(prompt)["sample"][0]  
    
image.save("test.png")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /var/folders/8w/r102wlvn3kg1238fnp7fwgn80000gn/T/ipykernel_52693/3068120375.py in <module>
#       1 prompt = "girl"
# ----> 2 image = pipe(prompt)["sample"][0]
#       3
#       4 image.save("test.png")
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.clone():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion.py in __call__(self, prompt, height, width, num_inference_steps, guidance_scale, negative_prompt, num_images_per_prompt, eta, generator, latents, output_type, return_dict, callback, callback_steps)
#     494
#     495         # 3. Encode input prompt
# --> 496         text_embeddings = self._encode_prompt(
#     497             prompt, device, num_images_per_prompt, do_classifier_free_guidance, negative_prompt
#     498         )
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/diffusers/pipelines/stable_diffusion/pipeline_stable_diffusion.py in _encode_prompt(self, prompt, device, num_images_per_prompt, do_classifier_free_guidance, negative_prompt)
#     263             attention_mask = None
#     264
# --> 265         text_embeddings = self.text_encoder(
#     266             text_input_ids.to(device),
#     267             attention_mask=attention_mask,
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py in forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#     731         >>> pooled_output = outputs.pooler_output  # pooled (EOS token) states
#     732         ```"""
# --> 733         return self.text_model(
#     734             input_ids=input_ids,
#     735             attention_mask=attention_mask,
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py in forward(self, input_ids, attention_mask, position_ids, output_attentions, output_hidden_states, return_dict)
#     647             attention_mask = _expand_mask(attention_mask, hidden_states.dtype)
#     648
# --> 649         encoder_outputs = self.encoder(
#     650             inputs_embeds=hidden_states,
#     651             attention_mask=attention_mask,
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py in forward(self, inputs_embeds, attention_mask, causal_attention_mask, output_attentions, output_hidden_states, return_dict)
#     576                 )
#     577             else:
# --> 578                 layer_outputs = encoder_layer(
#     579                     hidden_states,
#     580                     attention_mask,
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/transformers/models/clip/modeling_clip.py in forward(self, hidden_states, attention_mask, causal_attention_mask, output_attentions)
#     318         residual = hidden_states
#     319
# --> 320         hidden_states = self.layer_norm1(hidden_states)
#     321         hidden_states, attn_weights = self.self_attn(
#     322             hidden_states=hidden_states,
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#    1128         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1129                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1130             return forward_call(*input, **kwargs)
#    1131         # Do not call functions when jit is used
#    1132         full_backward_hooks, non_full_backward_hooks = [], []
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/nn/modules/normalization.py in forward(self, input)
#     187
#     188     def forward(self, input: Tensor) -> Tensor:
# --> 189         return F.layer_norm(
#     190             input, self.normalized_shape, self.weight, self.bias, self.eps)
#     191
#
# /Applications/anaconda3/envs/spacy3/lib/python3.9/site-packages/torch/nn/functional.py in layer_norm(input, normalized_shape, weight, bias, eps)
#    2501             layer_norm, (input, weight, bias), input, normalized_shape, weight=weight, bias=bias, eps=eps
#    2502         )
# -> 2503     return torch.layer_norm(input, normalized_shape, weight, bias, eps, torch.backends.cudnn.enabled)
#    2504
#    2505
#
# RuntimeError: "LayerNormKernelImpl" not implemented for 'Half'

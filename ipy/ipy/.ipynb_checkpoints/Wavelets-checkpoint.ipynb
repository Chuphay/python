# %%
L = 10
n = 2048
t2 = linspace(0,L,n+1)
t = t2[:n]
k = 2*pi/L*append(arange(n/2),arange(-n/2, 0))
ks = fftshift(k)
S = 6*sin(38*t)*exp(-t)-2*exp(-(t-3)**2)+2*cos(2*t)-(t-2)*(t-5)/6.5+4*sin(10*t)*exp(-t/3)+3*cos(15*t)*exp(-(t-7)**2) -4*sin(2.5*t)
print type(S)                     
subplot(211)
plot(t,S)    

from scipy.fftpack import fft
subplot(212)
TS = fft(S)

xlim(-30,30)
plot(ks,abs(fftshift(TS))/max(fftshift(TS)))
# Out:
# <type 'numpy.ndarray'>

# %%
globals()
"""
fft': <module 'numpy.fft' from '/usr/local/lib/python2.7/dist-packages/numpy/fft/__init__.pyc'>,
 'fft2': <function numpy.fft.fftpack.fft2>,
 'fftfreq': <function numpy.fft.helper.fftfreq>,
 'fftn': <function numpy.fft.fftpack.fftn>,
 'fftpack': <module 'numpy.fft.fftpack' from '/usr/local/lib/python2.7/dist-packages/numpy/fft/fftpack.pyc'>,
 'fftpack_lite': <module 'numpy.fft.fftpack_lite' from '/usr/local/lib/python2.7/dist-packages/numpy/fft/fftpack_lite.so'>,
 'fftshift': <function numpy.fft.helper.fftshift>,
 'fftsurr': <function matplotlib.mlab.fftsurr>,
 """
print

# %%
figsize(20,20)

slide = linspace(0,10,101)
import time
from IPython import display

"""
width = 10
for s in slide:
    f = exp(-width*(t-s)**2)
    sf = S*f
    sft = fft(sf)
    display.clear_output()


    subplot(4,1,2), plot(t,S/max(S),t,f)
    subplot(4,1,3), plot(t,sf)
    subplot(4,1,4), plot(ks,abs(fftshift(sft))), xlim(-30,30)
    display.display(plt.gcf())
    time.sleep(0.2)
    show()
   
"""
width = 10

data = []
for s in slide:
    f = exp(-width*(t-s)**2)
    sf = S*f
    sft = fft(sf)
    #subplot(4,1,2), plot(t,S/max(S),t,f)
    subplot(4,1,3), plot(t,sf)
    subplot(4,1,4), plot(ks,(fftshift(sft))), xlim(-30,30)
    data.append(abs(fftshift(sft)))

# %%
from pandas import DataFrame
specto = DataFrame(data)
specto[:5]
data2 = array(data)

data3 = data2[:100].T
figsize(10,10)
plt.pcolor(slide,ks,data3,  cmap="hot")
plt.ylim(-40, 40)
plt.colorbar()
plt.xlabel("t")
plt.ylabel("omega")
plt.show()

# %%
#http://nbviewer.ipython.org/github/c3h3/Computational-Methods-for-Data-Analysis/tree/master/
import numpy as np
import matplotlib.pyplot as plt

L = 10
n = 2048
t2 = np.linspace(0,L,n+1)
t = t2[:-1]
k = (2*np.pi/L)*np.fft.fftfreq(n,1.0/n)
ks = np.fft.ifftshift(k)

S = (3*np.sin(2*t) + 0.5*np.tanh(0,5*(t-3)) + 0.28*np.exp(-(t-4)**2) \
     + 1.5*np.sin(5*t) + 4*np.cos(3*(t-6)**2))/10 + (t/20)**3

width = 1
slides = np.arange(0,10,0.1)
spec = np.array([])
spec_n = np.array([])
for i in range(len(slides)):
    f = np.exp(-width*(t-slides[i])**2)
    Sf = np.prod(np.c_[f,S],axis=1)
    Sft = np.fft.fft(Sf)

    if i == 0:
        spec = np.r_[spec,np.abs(np.fft.fftshift(Sft))]
        #spec_n = np.r_[spec_n,np.abs(np.fft.fftshift(Sft))/max(np.abs(np.fft.fftshift(Sft)))]
    else:
        spec = np.c_[spec,np.abs(np.fft.fftshift(Sft))]

print len(slides), len(ks), len(spec)
plt.pcolor(slides,ks,spec,  cmap="hot")
plt.ylim(-50, 50)
plt.colorbar()
plt.xlabel("t")
plt.ylabel("omega")
plt.show()
# Out:
# 100 2048 2048

# %%
# Out:
# array([[  1.35256516,   1.35144992,   1.32729741,   1.28147165,
#           1.21666887,   1.13682843,   1.04694037,   0.95276563,
#           0.86053874,   0.77686775,   0.70935182,   0.66876892,
#           0.6729548 ,   0.74869245,   0.925883  ,   1.23012271,
#           1.68453952,   2.31510945,   3.15214767,   4.22862117,
#           5.57706836,   7.22577911,   9.19446927,  11.48972407,
#          14.10062495,  16.99509026,  20.11751094,  23.38822846,
#          26.70527313,  29.94856104,  32.98645712,  35.68428796,
#          37.91408093,  39.56456818,  40.55037452,  40.81933517,
#          40.35707126,  39.18826482,  37.37447625,  35.0087731 ,
#          32.20782257,  29.10238235,  25.82726576,  22.51184311,
#          19.27198531,  16.20409386,  13.38154268,  10.85353731,
#           8.64612055,   6.76485697,   5.19862455,   3.92393019,
#           2.90923001,   2.11885061,   1.51624919,   1.06649669,
#           0.73801829,   0.50382721,   0.34292921,   0.2435451 ,
#           0.20812178,   0.24354437,   0.34292676,   0.50382073,
#           0.73800301,   1.06646291,   1.51617792,   2.11870591,
#           2.90894602,   3.92338998,   5.19762659,   6.76306378,
#           8.64298222,  10.84818116,  13.37261833,  16.18956178,
#          19.24883575,  22.47573178,  25.77205373,  29.01956923,
#          32.08586743,  34.83230589,  37.12341768,  38.83689603,
#          39.87312871,  40.16325172,  39.6748416 ,  38.41464875,
#          36.42814471,  33.79604983,  30.6283571 ,  27.05661654,
#          23.22536913,  19.28363801,  15.37739342,  11.64417832,
#           8.21262706,   5.21772172,   2.89400094,   1.98017105],
#        [  1.17432641,   1.17902451,   1.16424237,   1.12998319,
#           1.07707187,   1.00704555,   0.9218987 ,   0.82368302,
#           0.71398766,   0.59334536,   0.46062022,   0.31244412,
#           0.14308678,   0.06564853,   0.31025199,   0.62252577,
#           1.02350865,   1.54198835,   2.21148104,   3.06884449,
#           4.15220763,   5.4981323 ,   7.13806409,   9.09423281,
#          11.37528558,  13.97206435,  16.85404805,  19.96703345,
#          23.2326042 ,  26.54981722,  29.79932213,  32.84984233,
#          35.56662196,  37.82113276,  39.50109154,  40.51971118,
#          40.82312781,  40.39512052,  39.25854836,  37.47332785,
#          35.13119987,  32.34792232,  29.25381254,  25.98371229,
#          22.66744129,  19.42165528,  16.34376696,  13.50827116,
#          10.96549436,   8.74251054,   6.8457641 ,   5.26483325,
#           3.97675241,   2.95037328,   2.15036056,   1.54056514,
#           1.08669519,   0.75847047,   0.53199233,   0.39390011,
#           0.34587481,   0.39389874,   0.53198879,   0.75846289,
#           1.08668002,   1.54053619,   2.15030753,   2.95027988,
#           3.97659421,   5.264576  ,   6.84536366,   8.74191705,
#          10.96466419,  13.50719241,  16.34250567,  19.42043068,
#          22.66673813,  25.98443482,  29.25747759,  32.35687612,
#          35.14882498,  37.50418458,  39.30837237,  40.47058293,
#          40.93126607,  40.66697025,  39.69198737,  38.0566697 ,
#          35.84275817,  33.1564827 ,  30.12048845,  26.86574989,
#          23.524534  ,  20.22518083,  17.08900522,  14.2289192 ,
#          11.74806043,   9.73406816,   8.24143839,   7.25941421]])

# %%
data = []
prob = 0.5
size = 15
figsize(12,8)
for i in range(size+1):
    for j in range(size+1):
        scatter(i,j,c='b')
        if(j<size and rand()>prob):
            data.append([j,j+1])
            data.append([i,i])
            data.append('k')
        if(i<size and rand()>prob):    
            data.append([j,j])
            data.append([i,i+1])
            data.append('k')
data = array(data)
print rand()
plot(*data)
show()
# Out:
# 0.792252877993

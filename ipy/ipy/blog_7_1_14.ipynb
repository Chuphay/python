# %%
data = []
for i in range(11):
    for j in range(11):
        scatter(i,j,c='b')
        data.append([j,j+1])
        data.append([i,i])
        data.append('k')
        data.append([j,j])
        data.append([i,i+1])
        data.append('k')
    #plot(i);
    #print i
    
#data = [i for i in range(10)]
data = array(data)
scatter(2.3,3.5,c='b')
#print data
#plot([0,1,0,1],[1,1,2,2])
#data=[[1, 1], [2, 3],  [2, 2], [4, 5],[5, 5], [6, 7]]
plot(*data)
show()

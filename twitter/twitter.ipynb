# %%
import twitter

# %%
access_token = "3161805806-5knas90qzqkaLqO11HY9KwhTWKFskukj45tUocP"
access_token_secret = "m1ILxyRFwCoPHzQ55MOieoUObjXh976vz3hcgUK1a8b2G"
consumer_key = "8sOsbXSPd9ZgAzOrrktEu9nKD"
consumer_secret = "pQbOdiJEjWqVrvUFXggcoGnSD9ZgxtXnBer4Xm4RRAmdFsc1G9"

twitter_stream = twitter.TwitterStream(auth=twitter.OAuth(
            token=access_token,
            token_secret=access_token_secret,
            consumer_key=consumer_key,
            consumer_secret=consumer_secret))

# %%
stream = twitter_stream.statuses.sample(block=True)

# %%
stream.__next__()
# Out:
# {'created_at': 'Fri Apr 24 21:13:54 +0000 2015',
#  'in_reply_to_status_id': None,
#  'text': 'http://t.co/NV4vcXumLq #stockings first #SinfulSunday #nsfw #adult #porn #Hannah Polites looking very fit! http://t.co/gKSzV4Qu4R',
#  'contributors': None,
#  'geo': None,
#  'entities': {'trends': [],
#   'symbols': [],
#   'media': [{'media_url': 'http://pbs.twimg.com/media/CDYupUEWgAIALjK.jpg',
#     'display_url': 'pic.twitter.com/gKSzV4Qu4R',
#     'expanded_url': 'http://twitter.com/stockingsfirst2/status/591711688468094976/photo/1',
#     'id_str': '591711688342274050',
#     'sizes': {'thumb': {'h': 150, 'resize': 'crop', 'w': 150},
#      'medium': {'h': 600, 'resize': 'fit', 'w': 600},
#      'small': {'h': 340, 'resize': 'fit', 'w': 340},
#      'large': {'h': 640, 'resize': 'fit', 'w': 640}},
#     'media_url_https': 'https://pbs.twimg.com/media/CDYupUEWgAIALjK.jpg',
#     'id': 591711688342274050,
#     'type': 'photo',
#     'indices': [107, 129],
#     'url': 'http://t.co/gKSzV4Qu4R'}],
#   'urls': [{'display_url': 'bit.ly/cIick4more?140…',
#     'expanded_url': 'http://bit.ly/cIick4more?1403249305995',
#     'indices': [0, 22],
#     'url': 'http://t.co/NV4vcXumLq'}],
#   'hashtags': [{'text': 'stockings', 'indices': [23, 33]},
#    {'text': 'SinfulSunday', 'indices': [40, 53]},
#    {'text': 'nsfw', 'indices': [54, 59]},
#    {'text': 'adult', 'indices': [60, 66]},
#    {'text': 'porn', 'indices': [67, 72]},
#    {'text': 'Hannah', 'indices': [73, 80]}],
#   'user_mentions': []},
#  'user': {'created_at': 'Fri Jun 20 07:22:44 +0000 2014',
#   'follow_request_sent': None,
#   'profile_sidebar_fill_color': 'DDEEF6',
#   'default_profile_image': True,
#   'friends_count': 0,
#   'protected': False,
#   'profile_image_url': 'http://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#   'profile_background_color': 'C0DEED',
#   'following': None,
#   'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#   'name': 'stockings first',
#   'id_str': '2578211658',
#   'id': 2578211658,
#   'time_zone': None,
#   'lang': 'de',
#   'favourites_count': 0,
#   'profile_sidebar_border_color': 'C0DEED',
#   'profile_use_background_image': True,
#   'profile_image_url_https': 'https://abs.twimg.com/sticky/default_profile_images/default_profile_1_normal.png',
#   'default_profile': True,
#   'profile_text_color': '333333',
#   'followers_count': 19,
#   'profile_background_tile': False,
#   'profile_link_color': '0084B4',
#   'description': None,
#   'verified': False,
#   'notifications': None,
#   'statuses_count': 26809,
#   'is_translator': False,
#   'geo_enabled': False,
#   'location': '',
#   'utc_offset': None,
#   'contributors_enabled': False,
#   'listed_count': 11,
#   'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#   'screen_name': 'stockingsfirst2',
#   'url': None},
#  'in_reply_to_user_id': None,
#  'place': None,
#  'id_str': '591711688468094976',
#  'id': 591711688468094976,
#  'favorite_count': 0,
#  'source': '<a href="http://ifttt.com" rel="nofollow">IFTTT</a>',
#  'possibly_sensitive': False,
#  'timestamp_ms': '1429910034659',
#  'in_reply_to_user_id_str': None,
#  'coordinates': None,
#  'lang': 'en',
#  'extended_entities': {'media': [{'media_url': 'http://pbs.twimg.com/media/CDYupUEWgAIALjK.jpg',
#     'display_url': 'pic.twitter.com/gKSzV4Qu4R',
#     'expanded_url': 'http://twitter.com/stockingsfirst2/status/591711688468094976/photo/1',
#     'id_str': '591711688342274050',
#     'sizes': {'thumb': {'h': 150, 'resize': 'crop', 'w': 150},
#      'medium': {'h': 600, 'resize': 'fit', 'w': 600},
#      'small': {'h': 340, 'resize': 'fit', 'w': 340},
#      'large': {'h': 640, 'resize': 'fit', 'w': 640}},
#     'media_url_https': 'https://pbs.twimg.com/media/CDYupUEWgAIALjK.jpg',
#     'id': 591711688342274050,
#     'type': 'photo',
#     'indices': [107, 129],
#     'url': 'http://t.co/gKSzV4Qu4R'}]},
#  'favorited': False,
#  'filter_level': 'low',
#  'in_reply_to_screen_name': None,
#  'truncated': False,
#  'in_reply_to_status_id_str': None,
#  'retweet_count': 0,
#  'retweeted': False}
